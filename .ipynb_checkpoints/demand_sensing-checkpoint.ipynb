# %% [markdown]
# # Opportunity 2

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %% [markdown]
# ## Data setup

# %%
data_dir = Path('data')
full_df = pd.concat(
    pd.read_parquet(parquet_file)
    for parquet_file in data_dir.glob('*.parquet*')
)
full_df
# Out:
#            BILL_DATE  MATERIAL SALES_DIST  SOLD_TO  SHIP_TO  PIEZAS
# 8511      2019-03-03      2641     100482  6001932  7003984       1
# 8512      2019-03-03     12916     100482  6001932  7003984       1
# 8513      2019-03-03      2464     100482  6001932  7003984       1
# 9478      2019-03-03     11074     100482  6001932  7003984       1
# 9479      2019-03-03     20306     100482  6001932  7003984       1
# ...              ...       ...        ...      ...      ...     ...
# 187373097 2021-03-31      2296     104862  6003121  7036861       1
# 187373098 2021-03-31      3590     104862  6003121  7036861       1
# 187373099 2021-03-31      8505     104862  6003121  7036861       1
# 187373100 2021-03-31     16951     104862  6003121  7036861       1
# 187373101 2021-03-31     19974     104862  6003121  7036861       1
#
# [30605 rows x 6 columns]

# %% [markdown]
# ## Top 10 most sold products

# %%
total_sales = full_df.groupby(['MATERIAL'])['PIEZAS'].sum()
total_sales = total_sales.sort_values(ascending=False)

top_10 = total_sales.head(10)
top_10
# Out:
# MATERIAL
# 1564     600
# 4373     379
# 3444     240
# 21256    222
# 6969     210
# 4103     207
# 15590    205
# 4101     200
# 42830    191
# 12091    184
# Name: PIEZAS, dtype: int64

# %% [markdown]
# ## Top 10 most sold products' weekly behaviour

# %%
top_10_weekly = {}

for mat_sales in top_10.T.iteritems():
    material = mat_sales[0]
    top_10_weekly[material] = full_df[full_df['MATERIAL'] == material]
    top_10_weekly[material]['Week'] = pd.to_datetime(top_10_weekly[material]['BILL_DATE']) - pd.to_timedelta(7, unit='d')
    top_10_weekly[material] =  top_10_weekly[material].filter(['Week', 'PIEZAS']).groupby([pd.Grouper(key='Week', freq='W-MON')]).sum().reset_index()

top_10_weekly
# Out:
# <ipython-input-106-ed4587b6efdf>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_10_weekly[material]['Week'] = pd.to_datetime(top_10_weekly[material]['BILL_DATE']) - pd.to_timedelta(7, unit='d')
# <ipython-input-106-ed4587b6efdf>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_10_weekly[material]['Week'] = pd.to_datetime(top_10_weekly[material]['BILL_DATE']) - pd.to_timedelta(7, unit='d')
# <ipython-input-106-ed4587b6efdf>:6: SettingWithCopyWarning:
# ...
